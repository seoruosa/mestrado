# %%
# %ls ../project/resultados/nsga_measurements/
# Out:
# measurements-20221031123834.txt  measurements-20221031160056.txt
# measurements-20221031123950.txt  measurements-20221031161020.txt
# measurements-20221031144726.txt  measurements-20221031161110.txt
# measurements-20221031145049.txt

# %%
filepath = "../project/resultados/nsga_measurements/measurements-20221031160056.txt"

# %%
import re
import pandas as pd

def read_nsga_measurements(filepath):
    re_two_points = re.compile(r'\s\:\s')

    dict_list = []
    i = 0
    with open(filepath, mode='r') as f:
        dict_el = {}
        for a in f.readlines():
            if ':' in a:
                b = re_two_points.split(a)
                dict_el[b[0]] = float(b[1])
            if ('*' in a) and (i > 0):
                dict_list.append(dict_el)
                dict_el = {}
            i = i + 1
    df = pd.DataFrame(dict_list)
    df.drop(columns=['generation'], inplace=True)
    
    return df

# %%
import matplotlib.pyplot as plt

df = read_nsga_measurements(filepath)
df.boxplot(rot=45, fontsize=15, figsize=(18, 12))
plt.show()

# %%
df.sum()
# Out:
# next_generation:generate                  8.130949
# next_generation:evaluate                 96.617726
# next_generation:insert                    0.087585
# next_generation:fast_sort                 1.076665
# next_generation:select_except_last        0.000900
# next_generation:crowd_sort_and_finish    62.042221
# dtype: float64

# %%
filepath = "../project/resultados/nsga_measurements/measurements-20221031161110.txt"

df = read_nsga_measurements(filepath)
df.boxplot(rot=45, fontsize=15, figsize=(18, 12))
plt.title("MG-d8_8", fontsize=15)
plt.show()

# %%
df.sum()
# Out:
# next_generation:generate                 113.023351
# next_generation:evaluate                 109.589562
# next_generation:insert                     0.742019
# next_generation:fast_sort                  3.620692
# next_generation:select_except_last         0.002657
# next_generation:crowd_sort_and_finish    109.491386
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17059 entries, 0 to 17058
# Data columns (total 6 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   next_generation:generate               17059 non-null  float64
#  1   next_generation:evaluate               17059 non-null  float64
#  2   next_generation:insert                 17059 non-null  float64
#  3   next_generation:fast_sort              17059 non-null  float64
#  4   next_generation:select_except_last     17059 non-null  float64
#  5   next_generation:crowd_sort_and_finish  17059 non-null  float64
# dtypes: float64(6)
# memory usage: 799.8 KB
